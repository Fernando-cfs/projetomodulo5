# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernando-cfs/projetomodulo5/blob/main/individualmodulo5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho individual módulo 5
#
# Você foi contratado como analista de dados e seu chefe, o Chief Marketing
# Officer (CMO), pediu que você trabalhasse com seu Parceiro de Negócios
# de Recursos Humanos (HRBP) para entender o que está causando o
# atrito – pessoas deixando a empresa – em toda a organização de
# marketing e apresentar suas descobertas.
#
# Nessa pesquisa foi gerado os sequintes dados de saida tanto pela empresa quanto perguntado para o funcionarios
#
# vamos analisar o grafico e explicar os motivos de saida dos funcionarios para que a empresa consiga entender melhor a saida e tentar melhora seu relacionamentos com os funcioanrios a rotatividades dos funcionarios gera prejuizo para empresa

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
imagem1 = cv2.imread('saida.jpg')
cv2_imshow(imagem1)
# Out:
# <PIL.Image.Image image mode=RGB size=1158x705>

# %% [markdown]
# Nessa analise preliminar foi gerado um grafico da HR Busines Partner Input e tambem um de quando perguntado para o funcionarios fora da pesquisa o Exit Survey vimos que a progresao de carreira e a que predomina nos dois graficos quanto ao motivo de saida vamos melhora esse grafico para uma melhor visualisasao para entender eles como uma melhor compraracao

# %% [markdown]
# - 1. O que está sendo mostrado aqui? Escreva um texto explicando os dados.
# Dica: imagine que você precisa explicar esse gráfico para o seu chefe. Escreva sobre como
# você faria isso em voz alta (fazendo suposições conforme necessário).

# %% [markdown]
# Nesse grafico mostra as diferentes razoes para saida dos funcionarios da empresa e seus impacto referente a cada saida e tambem os dados coletados da empresa ("HRBP" - Business Partner de Recursos Humanos) e a "saida da pesquisa" neles podemos ter uma comparacao

# %% [markdown]
# - 2. Que observações você pode fazer a partir desses dados? Coloque duas
# conclusões específicas em palavras. Escreva sentenças completas.

# %% [markdown]
# Os principais motivos da saida e tem o maior impactor e o avanco na carreira e e mencionado tanto na 'HRBP' quanto na 'sair da pesuisa' ou seja os funcionarios quando nao tem mais expectativa de crescimento eles busca novas oportunidades em outros lugares que tem melhor propostas de crecimento e desenvolvimento em suas carreiras
#
# O treinamento tem um forte impacto, mais e menos mensionados pela 'HRBPs' e no 'sair da pesquisa'  quando perguntado aos funcionarios

# %% [markdown]
# - 3. O que não é ideal ou poderia ser evitado na visualização em sua forma atual? Que perguntas você faria ou que feedback daria para quem fez o gráfico? Exemplo: suponha que seu HRBP gastou muito tempo criando esse gráfico; como você
# pode ajustar seu feedback para que ele não se ofenda?

# %% [markdown]
# A visualizao nao mostra os totais de funcionarios entrevistador o que dificulta um levantamento da quantidate total e percentuais para ter uma ideia geral das pessoas entrevistadas as bolas fica dispersas com valores dentro  no quadrante dificultando o entendimento

# %%
imagem2 = cv2.imread('total.jpg')
cv2_imshow(imagem2)
# Out:
# <PIL.Image.Image image mode=RGB size=550x415>

# %% [markdown]
# Essa tabela mostra a quantidades de participantes que responderam a pesquisa de saida e da HRBP e o total dos estrevistados, vimos que a HRBP teve mais entrevistados com o total de 565

# %%
imagem3 = cv2.imread('comparacao.jpg')
cv2_imshow(imagem3)
# Out:
# <PIL.Image.Image image mode=RGB size=1435x796>

# %%
imagem4 = cv2.imread('sairdaempresa.jpg')
cv2_imshow(imagem4)
# Out:
# <PIL.Image.Image image mode=RGB size=1433x611>

# %% [markdown]
# - 4. Crie três maneiras diferentes de mostrar esses dados e liste quais são algumas vantagens e insuficiências de cada uma.
#
# Foi criado um frafico mostrando o total de participantes entrevistados, um de barra comparando os impacto e as pesquisar da HRBP e de pesquisa de saida, outro grafico so comparando o HRBP e pesquisa de saida

# %% [markdown]
# - 5. Qual visualização representa melhor os dados e por quê?
#
# O grafico de barras e uma boa escolha para ver as diferenca entre as duas pesquisar e o impacto de cada uma delas com o total dos entrevistador tambem melhora a visualizacao da quntidade de funcioanrios entrevistados

# %% [markdown]
# - 6. Como você pode gerar essas informações em uma história orientada por dados
# para seu chefe? O objetivo é pensar além de mostrar simplesmente dados e mostrar
# o contexto da história.
#
# Com esses dados podemos visualizar um ideia geral dos funcionarios da empresa e com isso temos insgths importante para avaliarmos uma posivel postura da empresa para reter esses fucionarios
#
# saber o que os funcionarios estao buscando e ajudando na sua melhoria trara um grande crescimento para empresas com pessoas mais qualificadas e motivadas para desempenhar melhor suas funções e com isso cliente ainda mais satisfeitos
#
# As pessoas sao motivadas por desafios, crescimento pessoas ou mudanca de carreira ou um novo cargo mais que gere desafio para os funcionarios e algo que a empresa deve sempre buscar para as pessoas se sentirem motivadas
